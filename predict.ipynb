# %%
import torch
from torchvision.transforms import transforms
from PIL import Image
from pathlib import Path
import NewAlexNet

model = torch.load('/home/trainee/Intern/DRDO/alex.pth')
#model.load_state_dict('/home/trainee/Intern nit uk/DRDO/model1.pth')


model.eval()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (13): Conv2d(256, 9216, kernel_size=(1, 1), stride=(1, 1))
#     (14): ReLU(inplace)
#     (15): Conv2d(9216, 4096, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
import torchvision
from pylab import *
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
i=1
path='/home/trainee/Intern/DRDO/for_prediction/ant/'
data_trans = transforms.Compose([
        #transforms.Resize(input_size),
        #transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])


classify=['ant','bee']
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#subplot
images=os.listdir(path)
for image in images:
#     im=mpimg.imread(os.join)
    #print(os.path.join(path,image))
    test_image = Image.open(Path(os.path.join(path,image)))
    im1=mpimg.imread(os.path.join(path,image))
    im=data_trans(test_image)
    im=im.reshape(1,*im.shape)
    im=im.to(device)
    output = model(im)
    #im.shape
    output
    _, preds = torch.max(output, 1)
#     print(preds)
#     preds.cpu()

    preds_np=np.array(preds.cpu())
    plt.figure(figsize=(25,25))
    plt.subplot(15,5,i//5+i%5)
    plt.title(classify[preds_np.item()])
    plt.imshow(im1)
#     plt.plot(im1)
    plt.show()
    i+=1
#     preds
#     # preds=torch.from_numpy(preds)
#     preds_np=np.array(preds)

# # im1=mpimg.imread('/home/trainee/Intern nit uk/DRDO/an.jpg')
# image = Image.open(Path('/home/trainee/Intern nit uk/DRDO/an.jpg'))
# trans = transforms.ToPILImage()
# trans1 = transforms.ToTensor()
# image=image.resize((224,224))
# image=np.array(image)
# im=torch.from_numpy(image)
# image = torchvision.transforms.Tensor()
# image = torchvision.transforms.
#image = image.type(torch.FloatTensor)


# im=data_trans(image)

# im=im.reshape(1,*im.shape)
# im=im.to(device)
# output = model(im)
# #im.shape
# output
# _, preds = torch.max(output, 1)
# preds
# # preds=torch.from_numpy(preds)
# preds_np=np.array(preds)


# print(imag)
# plt.show(im1)
# cv2.imshow('image1',im1)
# plt.title(classify[preds_np.item()])
# plt.plot(im1)
# plt.imshow(im1)
# plt.show()
# print(im1shape)
# print(classify[preds_np.item()])
# prediction = int(torch.max(output.data, 1)[1].numpy())
# print(prediction)
